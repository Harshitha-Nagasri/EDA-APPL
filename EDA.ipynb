# %% [markdown]
# <a href="https://colab.research.google.com/github/Harshitha-Nagasri/EDA-APPL/blob/main/EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # EDA (EXPLORATORY DATA ANALYSIS)

# %% [markdown]
# ## 1. Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ##  2. Load Titanic Train Dataset

# %%
file=pd.read_csv('titanic_train.csv')
file.head(10)
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
# 5            6         0       3  ...   8.4583   NaN         Q
# 6            7         0       1  ...  51.8625   E46         S
# 7            8         0       3  ...  21.0750   NaN         S
# 8            9         1       3  ...  11.1333   NaN         S
# 9           10         1       2  ...  30.0708   NaN         C
#
# [10 rows x 12 columns]

# %% [markdown]
# ## 3. To Know The Values Are Null Or Not

# %%
file.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name  ...  Ticket   Fare  Cabin  Embarked
# 0          False     False   False  False  ...   False  False   True     False
# 1          False     False   False  False  ...   False  False  False     False
# 2          False     False   False  False  ...   False  False   True     False
# 3          False     False   False  False  ...   False  False  False     False
# 4          False     False   False  False  ...   False  False   True     False
# ..           ...       ...     ...    ...  ...     ...    ...    ...       ...
# 886        False     False   False  False  ...   False  False   True     False
# 887        False     False   False  False  ...   False  False  False     False
# 888        False     False   False  False  ...   False  False   True     False
# 889        False     False   False  False  ...   False  False  False     False
# 890        False     False   False  False  ...   False  False   True     False
#
# [891 rows x 12 columns]

# %% [markdown]
# ## 4. To Know How Many Values Are Null Values In Each Columns

# %%
count_of_missing_values=file.isnull().sum()
count_of_missing_values[0:12]
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# ## 5. To Know What Datatype It Is

# %%
file.Age.dtype
# Out:
# dtype('float64')

# %%
file.Parch.dtype
# Out:
# dtype('int64')

# %% [markdown]
# ## 6. To Fill NaN Values With Some Other Value

# %%
file.fillna('can\'t find')
# Out:
#      PassengerId  Survived  Pclass  ...     Fare       Cabin Embarked
# 0              1         0       3  ...   7.2500  can't find        S
# 1              2         1       1  ...  71.2833         C85        C
# 2              3         1       3  ...   7.9250  can't find        S
# 3              4         1       1  ...  53.1000        C123        S
# 4              5         0       3  ...   8.0500  can't find        S
# ..           ...       ...     ...  ...      ...         ...      ...
# 886          887         0       2  ...  13.0000  can't find        S
# 887          888         1       1  ...  30.0000         B42        S
# 888          889         0       3  ...  23.4500  can't find        S
# 889          890         1       1  ...  30.0000        C148        C
# 890          891         0       3  ...   7.7500  can't find        Q
#
# [891 rows x 12 columns]

# %% [markdown]
# ##  7. To replace anything in columns

# %%
file.Embarked.replace('S','H')
# Out:
# 0      H
# 1      C
# 2      H
# 3      H
# 4      H
#       ..
# 886    H
# 887    H
# 888    H
# 889    C
# 890    Q
# Name: Embarked, Length: 891, dtype: object

# %% [markdown]
# ## 8. Line Plot

# %%
plt.figure(figsize=(14,6))
plt.title("titanic data in lineplot")
sns.lineplot(data=file,x='Age',y='Survived')
plt.show()

# %% [markdown]
# ## 9. Bar Plot

# %%
sns.barplot(data=file,x="Sex",y="SibSp")

# %% [markdown]
# ## 10. Heatmap

# %%
plt.figure(figsize=(14,6))
sns.heatmap(file.isnull())

# %% [markdown]
# ## 11. Distplot

# %%
sns.distplot(file['Fare'].dropna(),color='blue',bins=10)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ## 12. Boxplot

# %%
plt.figure(figsize=(5,5))
sns.boxplot(x='Pclass',y='Embarked',data=file,palette='Dark2_r')

# %% [markdown]
# ## 13. Scatterplot

# %%
plt.figure(figsize=(14,6))
sns.scatterplot(x='Embarked',y='Age',data=file,palette='Dark2_r')

# %% [markdown]
# ## 14. Pairplot

# %%
plt.figure(figsize=(14,10))
sns.pairplot(file)

# %% [markdown]
# ## 15. Cleaning Dataset

# %%
file.drop('Ticket',axis=1,inplace=True)

# %%
file.head(100)
# Out:
#     PassengerId  Survived  Pclass  ...     Fare    Cabin  Embarked
# 0             1         0       3  ...   7.2500      NaN         S
# 1             2         1       1  ...  71.2833      C85         C
# 2             3         1       3  ...   7.9250      NaN         S
# 3             4         1       1  ...  53.1000     C123         S
# 4             5         0       3  ...   8.0500      NaN         S
# ..          ...       ...     ...  ...      ...      ...       ...
# 95           96         0       3  ...   8.0500      NaN         S
# 96           97         0       1  ...  34.6542       A5         C
# 97           98         1       1  ...  63.3583  D10 D12         C
# 98           99         1       2  ...  23.0000      NaN         S
# 99          100         0       2  ...  26.0000      NaN         S
#
# [100 rows x 11 columns]
